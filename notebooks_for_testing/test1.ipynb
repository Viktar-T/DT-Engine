# %% [markdown]
# Loading the Data

# %%
import sys
import os
print(os.getcwd())

# Add the project root directory to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, project_root)
print(project_root)
# Out:
# C:\Users\vtaustyka\PycharmProjects\DT-Engine\notebooks_for_testing
# C:\Users\vtaustyka\PycharmProjects\DT-Engine

# %%
import pandas as pd
from src.config import BASE_DIR, RAW_DATA_DIR

print(BASE_DIR)
print(RAW_DATA_DIR)
# Out:
# C:\Users\vtaustyka\PycharmProjects\DT-Engine
# C:\Users\vtaustyka\PycharmProjects\DT-Engine\data\raw

# %%
file_path11 = os.path.join(RAW_DATA_DIR, "all_csv", "2018-12", "1600Nn obc ON _ 2018-12-06.csv")

# Load a CSV file into a DataFrame
df = pd.read_csv(file_path11)

# Load an Excel file into a DataFrame
#df = pd.read_excel('filename.xlsx')

# Preview the first few rows
#df.head()

df.columns

# Preview the last few rows
#df.tail()
# Out:
# Index(['Czas [ms]', 'Ciś. pow. przed turb.[Pa]', 'Czas [ms].1',
#        'Ciś. pow. za turb.[Pa]', 'Czas [ms].2', 'Ciśnienie atmosferyczne[hPa]',
#        'Czas [ms].3', 'Ciśnienie oleju[bar]', 'Czas [ms].4',
#        'Ciśnienie spalin[Pa]',
#        ...
#        'Czas [ms].68', 'Zaw. zb. paliwa 2/3[-]', 'Czas [ms].69',
#        'Zaw. zb. paliwa 3/3[-]', 'Czas [ms].70', 'Zawór reg. chł. cieczy[-]',
#        'Czas [ms].71', 'Zużycie paliwa bieżące[g/s]', 'Czas [ms].72',
#        'Zużycie paliwa średnie[g/s]'],
#       dtype='object', length=149)

# %%
file_path21 = os.path.join(RAW_DATA_DIR, "all_csv", "2015-05", "1600 obc.csv")

# Load a CSV file into a DataFrame
df = pd.read_csv(file_path21)

# Load an Excel file into a DataFrame
#df = pd.read_excel('filename.xlsx')

# Preview the first few rows
#df.head()

df.columns

# Preview the last few rows
#df.tail()
# Out:
# Index(['Czas [ms];Ciś. pow. przed turb.[Pa];Czas [ms];Ciś. pow. za turb.[Pa];Czas [ms];Ciśnienie atmosferyczne[hPa];Czas [ms];Ciśnienie oleju[bar];Czas [ms];Ciśnienie spalin[Pa];Czas [ms];Dopeł. zb. 1/3[-];Czas [ms];Dopeł. zb. 2/3[-];Czas [ms];Dopeł. zb. 3/3[-];Czas [ms];Dopełnianie[-];Czas [ms];Duży obieg[-];Czas [ms];ECT - wejście do sil.[°C];Czas [ms];ECT - wyjście z sil.[°C];Czas [ms];Główny obieg - przepływ[m³/h];Czas [ms];Główny obieg - temp.[°C];Czas [ms];GPReg_Setpoint0[°C];Czas [ms];GPReg_Setpoint1[°C];Czas [ms];GPReg_Setpoint2[°C];Czas [ms];Hamulec',
#        ' lewa komora', ' temp.[°C];Czas [ms];Hamulec', ' prawa komora',
#        ' temp.[°C];Czas [ms];Hamulec.1',
# ...

# %%
file_path12 = os.path.join(RAW_DATA_DIR, "parquet_files", "1600Nn obc ON _ 2018-12-06 - 2018-12.parquet")

# Load a CSV file into a DataFrame
df = pd.read_parquet(file_path12)

# Load an Excel file into a DataFrame
#df = pd.read_excel('filename.xlsx')

# Preview the first few rows
#df.head()
df.columns

# Preview the last few rows
df.tail()
# Out:
#        Czas [ms]  Ciś. pow. przed turb.[Pa]  Czas [ms].1  \
# 38530        NaN                        NaN          NaN
# 38531        NaN                        NaN          NaN
# 38532        NaN                        NaN          NaN
# 38533        NaN                        NaN          NaN
# 38534        NaN                        NaN          NaN
#
#        Ciś. pow. za turb.[Pa]  Czas [ms].2  Ciśnienie atmosferyczne[hPa]  \
# 38530                     NaN          NaN                           NaN
# 38531                     NaN          NaN                           NaN
# 38532                     NaN          NaN                           NaN
# 38533                     NaN          NaN                           NaN
# 38534                     NaN          NaN                           NaN
#
#        Czas [ms].3  Ciśnienie oleju[bar]  Czas [ms].4  Ciśnienie spalin[Pa]  \
# 38530          NaN                   NaN          NaN                   NaN
# ...

# %%
file_path2 = os.path.join(RAW_DATA_DIR, "all_csv", "2018-12", "1600Nn obc ON _ 2018-12-06_ORIGEN.csv")

# Load a CSV file into a DataFrame
df = pd.read_csv(file_path2)

# Load an Excel file into a DataFrame
#df = pd.read_excel('filename.xlsx')

# Preview the first few rows
df.head()

# Preview the last few rows
df.tail()
# Out:
#        Czas [ms]  Ciś. pow. przed turb.[Pa]  Czas [ms].1  \
# 38530        NaN                        NaN          NaN
# 38531        NaN                        NaN          NaN
# 38532        NaN                        NaN          NaN
# 38533        NaN                        NaN          NaN
# 38534        NaN                        NaN          NaN
#
#        Ciś. pow. za turb.[Pa]  Czas [ms].2  Ciśnienie atmosferyczne[hPa]  \
# 38530                     NaN          NaN                           NaN
# 38531                     NaN          NaN                           NaN
# 38532                     NaN          NaN                           NaN
# 38533                     NaN          NaN                           NaN
# 38534                     NaN          NaN                           NaN
#
#        Czas [ms].3  Ciśnienie oleju[bar]  Czas [ms].4  Ciśnienie spalin[Pa]  \
# 38530          NaN                   NaN          NaN                   NaN
# ...

# %%
file_path3 = os.path.join(RAW_DATA_DIR, "parquet_files", "1600Nn obc ON _ 2018-12-06_ORIGEN - 2018-12.parquet")

# Load a CSV file into a DataFrame
df = pd.read_parquet(file_path3)

# Load an Excel file into a DataFrame
#df = pd.read_excel('filename.xlsx')

# Preview the first few rows
df.head()

# Preview the last few rows
df.tail()
# Out:
#        Czas [ms]  Ciś. pow. przed turb.[Pa]  Czas [ms].1  \
# 38530        NaN                        NaN          NaN
# 38531        NaN                        NaN          NaN
# 38532        NaN                        NaN          NaN
# 38533        NaN                        NaN          NaN
# 38534        NaN                        NaN          NaN
#
#        Ciś. pow. za turb.[Pa]  Czas [ms].2  Ciśnienie atmosferyczne[hPa]  \
# 38530                     NaN          NaN                           NaN
# 38531                     NaN          NaN                           NaN
# 38532                     NaN          NaN                           NaN
# 38533                     NaN          NaN                           NaN
# 38534                     NaN          NaN                           NaN
#
#        Czas [ms].3  Ciśnienie oleju[bar]  Czas [ms].4  Ciśnienie spalin[Pa]  \
# 38530          NaN                   NaN          NaN                   NaN
# ...
